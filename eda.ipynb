# %%
import pandas as pd

# %%
df = pd.read_csv("./outputs/stats_throughput_results.csv")

# %%
df.head(20)
# Out:
#             metric  batch_size precision baseline  n_baseline  n_precision  \
# 0   tokens_per_sec          32      fp16     fp32           3            3
# 1   tokens_per_sec          32      int4     fp32           3            3
# 2   tokens_per_sec          64      fp16     fp32           3            3
# 3   tokens_per_sec          64      int4     fp32           3            3
# 4   tokens_per_sec         128      fp16     fp32           3            3
# 5   tokens_per_sec         128      int4     fp32           3            3
# 6   tokens_per_sec         256      fp16     fp32           3            3
# 7   tokens_per_sec         256      int4     fp32           3            3
# 8   throughput_qps          32      fp16     fp32           3            3
# 9   throughput_qps          32      int4     fp32           3            3
# 10  throughput_qps          64      fp16     fp32           3            3
# ...
